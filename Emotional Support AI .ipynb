# %%
# Dependencies
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EntitiesOptions, KeywordsOptions, EmotionOptions

import os
import csv
import time
import random
import requests as req
import datetime
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import API Keys
from config import (consumer_key, consumer_secret, 
                    access_token, access_token_secret)

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
  username='f246d7f4-d9f0-4eaf-b832-b08f063b8d65',
  password='e5ZOMLB5730C',
  version='2018-03-16')

# %%
# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Term
target_term = "#feelingsad"

# %%
# Define function
def EmotionAnalysis():
    
    # Search for all tweets
    public_tweets = api.search(target_term, count=10, result_type="recent", lang="en")
    
    analyzed_tweets = []
    
    # Loop through all tweets
    for tweet in public_tweets["statuses"]:
        tweet_text = tweet["text"]
        tweet_id = tweet["id"]
        tweet_author = tweet["user"]["screen_name"]
        
        if tweet_id not in analyzed_tweets:
            analyzed_tweets.append(tweet_id)
            response = natural_language_understanding.analyze(
                text= tweet_text,
                features=Features(
                    emotion=EmotionOptions(
                    ))).get_result()
            
            jsonified_response = json.dumps(response, indent=2)
            sadness_level = json.loads(jsonified_response)["emotion"]["document"]["emotion"]["sadness"]

            
            if sadness_level > .70:
                try:
                    api.update_status("Hello @"+ tweet_author + "! It seems like you're having a rough time. Try visiting our website, it might help! www.emotionalsupportai.org")
                except Exception:
                    pass
                
            print("Tweet Author: " + tweet_author)
            print("Tweet ID: " + str(tweet_id))
            print("Sadness Level: " + str(sadness_level))
            print("Tweet Text: " + tweet_text)
            print("Analyzed Tweets: " + str(analyzed_tweets))
            print(json.dumps(response, indent=2))
            

            
            
            
#             print(json.loads(jsonified_response)["emotion"]["document"]["emotion"]["sadness"])

           
            
        if tweet_id in analyzed_tweets:
            print("We already anayzed this tweet: " + str(tweet_id))

# %%
# Run function at 5 minute intervals
while(True):
        EmotionAnalysis()
        time.sleep(300)
# Out:
# Tweet Author: BrianO_Malley
# Tweet ID: 1057663775501901824
# Sadness Level: 0.527841
# Tweet Text: RT @millenbrownact: Going to miss trick or treating tonight...pretty gutted. Havent been with my lad yet 😥.
# Sending love up to heaven for m…
# Analyzed Tweets: [1057663775501901824]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 140,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.527841,
#         "joy": 0.413871,
#         "fear": 0.064787,
#         "disgust": 0.036444,
#         "anger": 0.018538
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057663775501901824
# Tweet Author: AntonioEngr
# Tweet ID: 1057609173318295552
# Sadness Level: 0.284201
# Tweet Text: Exactly happening to me
# #FeelingSad https://t.co/8orPeuRuC6
# Analyzed Tweets: [1057663775501901824, 1057609173318295552]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 60,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.284201,
#         "joy": 0.155231,
#         "fear": 0.121612,
#         "disgust": 0.074291,
#         "anger": 0.090578
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057609173318295552
# Tweet Author: millenbrownact
# Tweet ID: 1057591094865735680
# Sadness Level: 0.527458
# Tweet Text: Going to miss trick or treating tonight...pretty gutted. Havent been with my lad yet 😥.
# Sending love up to heaven f… https://t.co/Gmg3aubxE1
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 140,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.527458,
#         "joy": 0.4118,
#         "fear": 0.073774,
#         "disgust": 0.023309,
#         "anger": 0.023487
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057591094865735680
# Tweet Author: cdupreegetaway
# Tweet ID: 1057413182850064384
# Sadness Level: 0.557673
# Tweet Text: Sadness is being human, the truck is to accept it and learn to be at peace within yourself. Try focus or find somet… https://t.co/3T2s2JYyOC
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 140,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.557673,
#         "joy": 0.424085,
#         "fear": 0.010182,
#         "disgust": 0.006915,
#         "anger": 0.009874
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057413182850064384
# Tweet Author: jihmns
# Tweet ID: 1057401026482003968
# Sadness Level: 0.318655
# Tweet Text: @vmnism she hit me with a k #feelingsad
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 39,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.318655,
#         "joy": 0.047562,
#         "fear": 0.279337,
#         "disgust": 0.151312,
#         "anger": 0.312087
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057401026482003968
# Tweet Author: westcountrybird
# Tweet ID: 1057343038974963713
# Sadness Level: 0.888708
# Tweet Text: Sad Doggy. #sadface #saddog #feelingsad #feelinglonely #missingher #lostherbestfriend #inmourning #missmybestfriend… https://t.co/Yr4f5lbJcU
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968, 1057343038974963713]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 140,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.888708,
#         "joy": 0.00646,
#         "fear": 0.185048,
#         "disgust": 0.073655,
#         "anger": 0.042103
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057343038974963713
# Tweet Author: DeeDeson1999
# Tweet ID: 1057248675884425216
# Sadness Level: 0.480244
# Tweet Text: im LOYAL. and no matter  how many times my loyalty has been abused,
# thats one characteristic  of mine  i will never change.
#
# #feelingSad
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968, 1057343038974963713, 1057248675884425216]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 136,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.480244,
#         "joy": 0.01541,
#         "fear": 0.09716,
#         "disgust": 0.32198,
#         "anger": 0.270582
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057248675884425216
# Tweet Author: myhalflovestory
# Tweet ID: 1057195005155164160
# Sadness Level: 0.233803
# Tweet Text: When I dropped you to the airport that night, I had a lot of things to say..!
# .
# .
# Follow 👉 @myhalflovestory… https://t.co/Ajf7PjUpf9
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968, 1057343038974963713, 1057248675884425216, 1057195005155164160]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 132,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.233803,
#         "joy": 0.420055,
#         "fear": 0.258002,
#         "disgust": 0.06219,
#         "anger": 0.103734
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057195005155164160
# Tweet Author: Aibileen7
# Tweet ID: 1057085574253670400
# Sadness Level: 0.938709
# Tweet Text: I miss Treelore #feelingsad 😔😭😭
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968, 1057343038974963713, 1057248675884425216, 1057195005155164160, 1057085574253670400]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 31,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.938709,
#         "joy": 0.019405,
#         "fear": 0.096867,
#         "disgust": 0.038581,
#         "anger": 0.00556
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057085574253670400
# Tweet Author: Abigail26974034
# Tweet ID: 1057020917950361600
# Sadness Level: 0.692185
# Tweet Text: Just got dumped 😔. But I know he'll give me another chance, our love is too strong #feelingsad #truelove
# Analyzed Tweets: [1057663775501901824, 1057609173318295552, 1057591094865735680, 1057413182850064384, 1057401026482003968, 1057343038974963713, 1057248675884425216, 1057195005155164160, 1057085574253670400, 1057020917950361600]
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 104,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.692185,
#         "joy": 0.220209,
#         "fear": 0.035766,
#         "disgust": 0.031581,
#         "anger": 0.012962
#       }
#     }
#   }
# }
# We already anayzed this tweet: 1057020917950361600
